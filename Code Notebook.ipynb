# %%
import pandas as pd

# %%
df=pd.read_excel('family_financial_and_transactions_data.xlsx')

# %%
df
# Out:
#       Family ID       Member ID Transaction Date       Category  Amount  \
# 0        FAM001  FAM001_Member1       2024-10-07         Travel  409.12
# 1        FAM001  FAM001_Member1       2024-10-16         Travel  270.91
# 2        FAM001  FAM001_Member1       2024-10-17      Groceries   91.10
# 3        FAM001  FAM001_Member1       2024-10-25     Healthcare  198.23
# 4        FAM001  FAM001_Member1       2024-10-25      Education  206.42
# ...         ...             ...              ...            ...     ...
# 16301    FAM200  FAM200_Member6       2024-10-10      Groceries   79.99
# 16302    FAM200  FAM200_Member6       2024-10-22      Education  228.39
# 16303    FAM200  FAM200_Member6       2024-10-29         Travel  258.63
# 16304    FAM200  FAM200_Member6       2024-10-26         Travel  467.46
# 16305    FAM200  FAM200_Member6       2024-10-27  Entertainment  475.34
#
#        Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# ...

# %%
df.columns
# Out:
# Index(['Family ID', 'Member ID', 'Transaction Date', 'Category', 'Amount',
#        'Income', 'Savings', 'Monthly Expenses', 'Loan Payments',
#        'Credit Card Spending', 'Dependents', 'Financial Goals Met (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16306 entries, 0 to 16305
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Family ID                16306 non-null  object
#  1   Member ID                16306 non-null  object
#  2   Transaction Date         16306 non-null  datetime64[ns]
#  3   Category                 16306 non-null  object
#  4   Amount                   16306 non-null  float64
#  5   Income                   16306 non-null  int64
#  6   Savings                  16306 non-null  int64
#  7   Monthly Expenses         16306 non-null  int64
#  8   Loan Payments            16306 non-null  int64
#  9   Credit Card Spending     16306 non-null  int64
#  10  Dependents               16306 non-null  int64
#  11  Financial Goals Met (%)  16306 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(3)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Family ID                  0
# Member ID                  0
# Transaction Date           0
# Category                   0
# Amount                     0
# Income                     0
# Savings                    0
# Monthly Expenses           0
# Loan Payments              0
# Credit Card Spending       0
# Dependents                 0
# Financial Goals Met (%)    0
# dtype: int64

# %%
df.describe()
# Out:
#                     Transaction Date        Amount         Income  \
# count                          16306  16306.000000   16306.000000
# mean   2024-10-16 00:34:31.777259776    256.368534   90340.503925
# min              2024-10-01 00:00:00     10.030000   30851.000000
# 25%              2024-10-08 00:00:00    134.820000   59871.000000
# 50%              2024-10-16 00:00:00    256.055000   90142.000000
# 75%              2024-10-24 00:00:00    379.240000  119733.000000
# max              2024-10-31 00:00:00    499.910000  149871.000000
# std                              NaN    141.153813   34740.834136
#
#             Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# count  16306.000000      16306.000000   16306.000000          16306.000000
# mean   24473.998038       3948.522384    2529.978965           1782.880535
# min     1037.000000       1013.000000       3.000000            510.000000
# ...

# %%
df['Family ID'].value_counts()
# Out:
# Family ID
# FAM194    167
# FAM005    165
# FAM187    156
# FAM050    155
# FAM071    144
#          ...
# FAM022     24
# FAM180     24
# FAM075     23
# FAM174     19
# FAM197     19
# Name: count, Length: 200, dtype: int64

# %%
df['Family ID'].nunique()
# Out:
# 200

# %%
df['Member ID'].value_counts()
# Out:
# Member ID
# FAM006_Member3    30
# FAM194_Member1    30
# FAM123_Member2    30
# FAM084_Member2    30
# FAM194_Member7    30
#                   ..
# FAM056_Member1     5
# FAM095_Member6     5
# FAM057_Member2     5
# FAM176_Member1     5
# FAM138_Member1     5
# Name: count, Length: 926, dtype: int64

# %%
df['Member ID'].nunique()
# Out:
# 926

# %%
df['Category'].value_counts()
# Out:
# Category
# Groceries        2390
# Entertainment    2383
# Utilities        2359
# Food             2355
# Education        2338
# Travel           2270
# Healthcare       2211
# Name: count, dtype: int64

# %%
# Extract the number after 'Member' and convert to integer
df['Member ID'].str.extract(r'Member(\d+)', expand=False).astype(int).max()
# Out:
# 7

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# Get value counts for 'Category'
category_counts = df['Category'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
category_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Blues')
plt.title('Distribution of Categories')
plt.ylabel('')  # Hide the y-axis label for aesthetics
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import seaborn as sns

# Extract the member number and count occurrences
member_counts = df['Member ID'].str.extract(r'Member(\d+)', expand=False).astype(int).value_counts()

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=member_counts.index, y=member_counts.values, palette="viridis")
plt.title("Family Member Distribution", fontsize=16)
plt.xlabel("Member Number", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

# Convert Transaction Date to datetime if not already
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# Group by Transaction Date and calculate the total amount for each date
date_amount = df.groupby('Transaction Date')['Monthly Expenses'].mean().reset_index()

# Plot the line chart
plt.figure(figsize=(14, 7))
plt.plot(date_amount['Transaction Date'], date_amount['Monthly Expenses'], marker='o', linestyle='-', color='blue', label='Total Amount')
plt.title("Transaction Date vs Monthly Expenses", fontsize=16)
plt.xlabel("Transaction Date", fontsize=14)
plt.ylabel("Monthly Expenses", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df
# Out:
#       Family ID       Member ID Transaction Date       Category  Amount  \
# 0        FAM001  FAM001_Member1       2024-10-07         Travel  409.12
# 1        FAM001  FAM001_Member1       2024-10-16         Travel  270.91
# 2        FAM001  FAM001_Member1       2024-10-17      Groceries   91.10
# 3        FAM001  FAM001_Member1       2024-10-25     Healthcare  198.23
# 4        FAM001  FAM001_Member1       2024-10-25      Education  206.42
# ...         ...             ...              ...            ...     ...
# 16301    FAM200  FAM200_Member6       2024-10-10      Groceries   79.99
# 16302    FAM200  FAM200_Member6       2024-10-22      Education  228.39
# 16303    FAM200  FAM200_Member6       2024-10-29         Travel  258.63
# 16304    FAM200  FAM200_Member6       2024-10-26         Travel  467.46
# 16305    FAM200  FAM200_Member6       2024-10-27  Entertainment  475.34
#
#        Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# ...

# %%
# Convert Transaction Date to datetime format if not already done
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# Extract the day of the week
df['Day of Week'] = df['Transaction Date'].dt.day_name()

# %%
# Calculate average monthly expenses by day of the week
day_expenses = df.groupby('Day of Week')['Monthly Expenses'].mean().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    day_expenses,
    labels=day_expenses.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=sns.color_palette("pastel"),
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)
plt.title("Average Monthly Expenses by Day of the Week", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Calculate average monthly expenses by category
category_expenses = df.groupby('Category')['Monthly Expenses'].mean()

# Plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(
    category_expenses,
    labels=category_expenses.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette("tab10"),
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)
plt.title("Average Monthly Expenses by Category", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Calculate average monthly expenses by category
category_expenses = df.groupby('Category')['Credit Card Spending'].mean()

# Plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(
    category_expenses,
    labels=category_expenses.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette("tab10"),
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)
plt.title("Average Credit Card Spending by Category", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Calculate average monthly expenses by category
category_expenses = df.groupby('Category')['Loan Payments'].mean()

# Plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(
    category_expenses,
    labels=category_expenses.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette("tab10"),
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)
plt.title("Average Loan Payments by Category", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count the occurrences of each number of dependents
dependents_counts = df['Dependents'].value_counts()

# Plot the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    x=dependents_counts.index, 
    y=dependents_counts.values, 
    palette='viridis'
)
plt.title("Distribution of Dependents", fontsize=16)
plt.xlabel("Number of Dependents", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Extract member numbers and calculate the mean Monthly Expenses for each member
member_expenses = df.groupby(df['Member ID'].str.extract(r'Member(\d+)', expand=False).astype(int))['Monthly Expenses'].mean().reset_index()
member_expenses.columns = ['Member Number', 'Monthly Expenses']

# Plot the line chart
plt.figure(figsize=(12, 6))
plt.plot(
    member_expenses['Member Number'], 
    member_expenses['Monthly Expenses'], 
    marker='o', linestyle='-', color='blue', label='Monthly Expenses'
)
plt.title("Average Monthly Expenses by Family Member", fontsize=16)
plt.xlabel("Family Member", fontsize=14)
plt.ylabel("Average Monthly Expenses", fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df
# Out:
#       Family ID       Member ID Transaction Date       Category  Amount  \
# 0        FAM001  FAM001_Member1       2024-10-07         Travel  409.12
# 1        FAM001  FAM001_Member1       2024-10-16         Travel  270.91
# 2        FAM001  FAM001_Member1       2024-10-17      Groceries   91.10
# 3        FAM001  FAM001_Member1       2024-10-25     Healthcare  198.23
# 4        FAM001  FAM001_Member1       2024-10-25      Education  206.42
# ...         ...             ...              ...            ...     ...
# 16301    FAM200  FAM200_Member6       2024-10-10      Groceries   79.99
# 16302    FAM200  FAM200_Member6       2024-10-22      Education  228.39
# 16303    FAM200  FAM200_Member6       2024-10-29         Travel  258.63
# 16304    FAM200  FAM200_Member6       2024-10-26         Travel  467.46
# 16305    FAM200  FAM200_Member6       2024-10-27  Entertainment  475.34
#
#        Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# ...

# %% [markdown]
# ## Financial Scoring Model

# %%
import pandas as pd
import numpy as np

def calculate_financial_health_score(df):
    """
    Calculate a financial health score (0-100) for each family based on various financial indicators.
    
    Parameters:
    df: pandas DataFrame containing family financial data
    
    Returns:
    DataFrame with original data and new financial health score column
    """
    # First, calculate category spending percentages for each family
    category_spending = df.groupby(['Family ID', 'Category'])['Amount'].sum().reset_index()
    total_spending = df.groupby('Family ID')['Amount'].sum().reset_index()
    category_spending = category_spending.merge(total_spending, on='Family ID', suffixes=('', '_total'))
    category_spending['spending_percentage'] = (category_spending['Amount'] / category_spending['Amount_total']) * 100

    # Group by Family ID to get family-level metrics
    family_metrics = df.groupby('Family ID').agg({
        'Income': 'first',
        'Savings': 'first',
        'Monthly Expenses': 'first',
        'Loan Payments': 'first',
        'Credit Card Spending': 'first',
        'Financial Goals Met (%)': 'first'
    }).reset_index()
    
    # 1. Savings-to-Income Ratio (25% weight)
    family_metrics['savings_score'] = (family_metrics['Savings'] / family_metrics['Income'] * 200).clip(0, 100)
    
    # 2. Monthly Expenses to Income Ratio (20% weight)
    family_metrics['expenses_score'] = (100 - (family_metrics['Monthly Expenses'] / family_metrics['Income'] * 100)).clip(0, 100)
    
    # 3. Loan Payments to Income Ratio (15% weight)
    family_metrics['loan_score'] = (100 - (family_metrics['Loan Payments'] / family_metrics['Income'] * 250)).clip(0, 100)
    
    # 4. Credit Card Spending to Income Ratio (15% weight)
    family_metrics['credit_score'] = (100 - (family_metrics['Credit Card Spending'] / family_metrics['Income'] * 300)).clip(0, 100)
    
    # 5. Spending Pattern Score (10% weight)
    category_weights = {
        'Travel': 0.6,
        'Entertainment': 0.7,
        'Dining': 0.8,
        'Shopping': 0.8,
        'Groceries': 1.0,
        'Healthcare': 1.0,
        'Education': 1.0,
        'Utilities': 1.0
    }
    
    # Calculate weighted spending score for each family
    category_spending['category_weight'] = category_spending['Category'].map(lambda x: category_weights.get(x, 0.9))
    category_spending['weighted_score'] = category_spending['spending_percentage'] * category_spending['category_weight']
    spending_pattern_scores = category_spending.groupby('Family ID')['weighted_score'].mean().reset_index()
    spending_pattern_scores['weighted_score'] = spending_pattern_scores['weighted_score'].clip(0, 100)
    
    # Merge spending pattern scores with family metrics
    family_metrics = family_metrics.merge(spending_pattern_scores, on='Family ID')
    family_metrics['spending_pattern_score'] = family_metrics['weighted_score']
    
    # 6. Financial Goals Score (15% weight)
    family_metrics['goals_score'] = family_metrics['Financial Goals Met (%)']
    
    # Calculate final weighted score
    family_metrics['financial_health_score'] = (
        family_metrics['savings_score'] * 0.25 +
        family_metrics['expenses_score'] * 0.20 +
        family_metrics['loan_score'] * 0.15 +
        family_metrics['credit_score'] * 0.15 +
        family_metrics['spending_pattern_score'] * 0.10 +
        family_metrics['goals_score'] * 0.15
    ).round(2)
    
    # Map scores back to original dataframe
    score_mapping = family_metrics[['Family ID', 'financial_health_score']].set_index('Family ID')['financial_health_score']
    df['Financial Health Score'] = df['Family ID'].map(score_mapping)
    
    return df

# Add health score column to the dataframe
df = calculate_financial_health_score(df)

# %%
df
# Out:
#       Family ID       Member ID Transaction Date       Category  Amount  \
# 0        FAM001  FAM001_Member1       2024-10-07         Travel  409.12
# 1        FAM001  FAM001_Member1       2024-10-16         Travel  270.91
# 2        FAM001  FAM001_Member1       2024-10-17      Groceries   91.10
# 3        FAM001  FAM001_Member1       2024-10-25     Healthcare  198.23
# 4        FAM001  FAM001_Member1       2024-10-25      Education  206.42
# ...         ...             ...              ...            ...     ...
# 16301    FAM200  FAM200_Member6       2024-10-10      Groceries   79.99
# 16302    FAM200  FAM200_Member6       2024-10-22      Education  228.39
# 16303    FAM200  FAM200_Member6       2024-10-29         Travel  258.63
# 16304    FAM200  FAM200_Member6       2024-10-26         Travel  467.46
# 16305    FAM200  FAM200_Member6       2024-10-27  Entertainment  475.34
#
#        Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# ...

# %% [markdown]
# ## Justification
#
# 1. Savings-to-Income Ratio (25% weight)
# - Highest weight (25%) because savings is crucial for:
#   - Emergency funds
#   - Long-term financial security
#   - Future investments and opportunities
# - Scoring logic: (Savings/Income × 200), capped at 100
# - Target: Ideal savings should be at least 50% of income
# - Rationale: Higher savings relative to income indicates better financial discipline and security
#
# 2. Monthly Expenses to Income Ratio (20% weight)
# - Second-highest weight due to its importance in day-to-day financial management
# - Scoring logic: 100 - (Monthly Expenses/Income × 100), capped at 100
# - Target: Expenses should not exceed 70% of income
# - Rationale:
#   - Lower expenses-to-income ratio indicates better budgeting
#   - Allows more room for savings and investments
#   - Provides buffer for unexpected expenses
#
# 3. Loan Payments to Income Ratio (15% weight)
# - Scoring logic: 100 - (Loan Payments/Income × 250), capped at 100
# - Target: Loan payments should be below 40% of income
# - Rationale:
#   - High debt burden increases financial risk
#   - Impacts ability to save and invest
#   - Affects credit worthiness
#   - Factor in debt-to-income ratio standards used by lenders
#
# 4. Credit Card Spending to Income Ratio (15% weight)
# - Scoring logic: 100 - (Credit Card Spending/Income × 300), capped at 100
# - Target: Credit card spending should be below 30% of income
# - Rationale:
#   - High credit card usage often indicates cash flow problems
#   - Risk of high-interest debt accumulation
#   - Impacts credit utilization ratio
#   - Important for short-term financial health
#
# 5. Discretionary Spending Pattern Score (10% weight)
# - Lower weight as some discretionary spending is normal and necessary
# - Category weights:
#   - Essential categories (1.0): Groceries, Healthcare, Education, Utilities
#   - Moderate impact (0.8): Dining, Shopping
#   - Higher impact (0.6-0.7): Travel, Entertainment
# - Rationale:
#   - Balances necessity vs. luxury spending
#   - Rewards essential spending
#   - Accounts for quality of life while maintaining financial responsibility
#
# 6. Financial Goals Met (15% weight)
# - Directly uses the provided Financial Goals Met percentage
# - Rationale:
#   - Indicates financial discipline and planning ability
#   - Measures commitment to financial improvement
#   - Reflects ability to set and achieve financial targets
#   - Shows long-term financial management capability
#
# Additional Considerations in the Scoring System:
#
# 1. Scale Normalization:
# - All scores are normalized to 0-100 scale
# - Makes components comparable and easy to understand
# - Allows for consistent weighting
#
# 2. Weight Distribution:
# - Core financial health indicators (savings, expenses) = 45%
# - Debt management (loans, credit cards) = 30%
# - Behavioral factors (spending patterns, goals) = 25%
# - This distribution prioritizes fundamental financial stability while considering behavioral aspects
#
# 3. Scoring Thresholds:
# - Based on common financial planning guidelines
# - Aligned with industry standards for debt-to-income ratios
# - Considers realistic achievable targets for average families
#
# 4. Score Interpretation:
# - 90-100: Excellent financial health
# - 80-89: Good financial management
# - 70-79: Satisfactory financial condition
# - 60-69: Needs improvement
# - Below 60: Requires significant attention
#
# This scoring system provides a balanced assessment of financial health by:
# - Emphasizing long-term financial security (savings)
# - Considering day-to-day financial management (expenses)
# - Including debt management practices
# - Accounting for spending behavior
# - Incorporating goal achievement
# - Using industry-standard financial ratios and benchmarks

# %%
df.to_csv('training.csv',index=False)

# %% [markdown]
# # ML Model

# %%
df=pd.read_csv('training.csv')

# %%
df['Total Members']=df['Member ID'].str.extract(r'Member(\d+)', expand=False).astype(int)

# %%
df
# Out:
#       Family ID       Member ID Transaction Date       Category  Amount  \
# 0        FAM001  FAM001_Member1       2024-10-07         Travel  409.12
# 1        FAM001  FAM001_Member1       2024-10-16         Travel  270.91
# 2        FAM001  FAM001_Member1       2024-10-17      Groceries   91.10
# 3        FAM001  FAM001_Member1       2024-10-25     Healthcare  198.23
# 4        FAM001  FAM001_Member1       2024-10-25      Education  206.42
# ...         ...             ...              ...            ...     ...
# 16301    FAM200  FAM200_Member6       2024-10-10      Groceries   79.99
# 16302    FAM200  FAM200_Member6       2024-10-22      Education  228.39
# 16303    FAM200  FAM200_Member6       2024-10-29         Travel  258.63
# 16304    FAM200  FAM200_Member6       2024-10-26         Travel  467.46
# 16305    FAM200  FAM200_Member6       2024-10-27  Entertainment  475.34
#
#        Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# ...

# %%
df.describe()
# Out:
#              Amount         Income       Savings  Monthly Expenses  \
# count  16306.000000   16306.000000  16306.000000      16306.000000
# mean     256.368534   90340.503925  24473.998038       3948.522384
# std      141.153813   34740.834136  14828.955695       1689.987801
# min       10.030000   30851.000000   1037.000000       1013.000000
# 25%      134.820000   59871.000000  11016.000000       2582.000000
# 50%      256.055000   90142.000000  25504.000000       3721.000000
# 75%      379.240000  119733.000000  37422.000000       5450.000000
# max      499.910000  149871.000000  49217.000000       6968.000000
#
#        Loan Payments  Credit Card Spending    Dependents  \
# count   16306.000000          16306.000000  16306.000000
# mean     2529.978965           1782.880535      3.201521
# std      1384.105561            716.595101      1.468880
# min         3.000000            510.000000      0.000000
# 25%      1390.000000           1221.000000      2.000000
# ...

# %%
df=df[['Category','Amount','Income',	'Savings',	'Monthly Expenses'	,'Loan Payments',	'Credit Card Spending',	'Dependents','Financial Goals Met (%)',	'Day of Week','Total Members','Financial Health Score']]

# %%
df
# Out:
#             Category  Amount  Income  Savings  Monthly Expenses  \
# 0             Travel  409.12  113810    20234              5781
# 1             Travel  270.91  113810    20234              5781
# 2          Groceries   91.10  113810    20234              5781
# 3         Healthcare  198.23  113810    20234              5781
# 4          Education  206.42  113810    20234              5781
# ...              ...     ...     ...      ...               ...
# 16301      Groceries   79.99   44621    44081              4296
# 16302      Education  228.39   44621    44081              4296
# 16303         Travel  258.63   44621    44081              4296
# 16304         Travel  467.46   44621    44081              4296
# 16305  Entertainment  475.34   44621    44081              4296
#
#        Loan Payments  Credit Card Spending  Dependents  \
# 0               2422                  2959           2
# 1               2422                  2959           2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16306 entries, 0 to 16305
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Category                 16306 non-null  object
#  1   Amount                   16306 non-null  float64
#  2   Income                   16306 non-null  int64
#  3   Savings                  16306 non-null  int64
#  4   Monthly Expenses         16306 non-null  int64
#  5   Loan Payments            16306 non-null  int64
#  6   Credit Card Spending     16306 non-null  int64
#  7   Dependents               16306 non-null  int64
#  8   Financial Goals Met (%)  16306 non-null  int64
#  9   Day of Week              16306 non-null  object
#  10  Total Members            16306 non-null  int32
#  11  Financial Health Score   16306 non-null  float64
# dtypes: float64(2), int32(1), int64(7), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Linear Regression

# %%
x=df.drop(columns=['Financial Health Score'])

# %%
y=df['Financial Health Score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#          Category  Amount  Income  Savings  Monthly Expenses  Loan Payments  \
# 10315   Utilities  144.79  135518    13025              1317            237
# 4245       Travel  244.61   42156    14880              1945            873
# 3728   Healthcare  274.82   66421    37031              5543           3145
# 10884   Utilities  269.05  144867     4315              2826            220
# 11573  Healthcare  106.00  145957    27634              1568           1111
# ...           ...     ...     ...      ...               ...            ...
# 13418   Education  438.33   96784    13445              3569           1836
# 5390       Travel   33.40  102357    15725              3057           2599
# 860     Groceries  141.48  118696    34271              3175           4488
# 15795   Utilities  177.97  128419    39962              5154           1624
# 7270       Travel  252.10   66434    32812              5469           4424
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoders
category_encoder = LabelEncoder()
day_encoder = LabelEncoder()

# Fit encoders on the training data
X_train['Category'] = category_encoder.fit_transform(X_train['Category'])
X_train['Day of Week'] = day_encoder.fit_transform(X_train['Day of Week'])

# Transform the test data using the fitted encoders
X_test['Category'] = category_encoder.transform(X_test['Category'])
X_test['Day of Week'] = day_encoder.transform(X_test['Day of Week'])

# If you want to see the mappings
category_mapping = dict(zip(category_encoder.classes_, category_encoder.transform(category_encoder.classes_)))
day_mapping = dict(zip(day_encoder.classes_, day_encoder.transform(day_encoder.classes_)))

print("Category Mapping:", category_mapping)
print("Day of Week Mapping:", day_mapping)
# Out:
# Category Mapping: {'Education': 0, 'Entertainment': 1, 'Food': 2, 'Groceries': 3, 'Healthcare': 4, 'Travel': 5, 'Utilities': 6}
# Day of Week Mapping: {'Friday': 0, 'Monday': 1, 'Saturday': 2, 'Sunday': 3, 'Thursday': 4, 'Tuesday': 5, 'Wednesday': 6}

# %%
X_train
# Out:
#        Category  Amount  Income  Savings  Monthly Expenses  Loan Payments  \
# 10315         6  144.79  135518    13025              1317            237
# 4245          5  244.61   42156    14880              1945            873
# 3728          4  274.82   66421    37031              5543           3145
# 10884         6  269.05  144867     4315              2826            220
# 11573         4  106.00  145957    27634              1568           1111
# ...         ...     ...     ...      ...               ...            ...
# 13418         0  438.33   96784    13445              3569           1836
# 5390          5   33.40  102357    15725              3057           2599
# 860           3  141.48  118696    34271              3175           4488
# 15795         6  177.97  128419    39962              5154           1624
# 7270          5  252.10   66434    32812              5469           4424
#
#        Credit Card Spending  Dependents  Financial Goals Met (%)  Day of Week  \
# ...

# %% [markdown]
# ### Multivariate Normality

# %%
import scipy.stats as stats

# Fit a simple linear regression model
from sklearn.linear_model import LinearRegression


model = LinearRegression().fit(X_train, y_train)
residuals = y_test - model.predict(X_test)

# Histogram
sns.histplot(residuals, kde=True)
plt.title("Histogram of Residuals")
plt.show()

# Q-Q Plot
stats.probplot(residuals, dist="norm", plot=plt)
plt.show()

# %% [markdown]
# ### Homoscedasticity

# %%
# Residuals vs Predicted
y_pred = model.predict(X_test)
sns.scatterplot(x=y_pred, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals vs Predicted Values")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# The variation of residuals is not evenly distributed, indicating heteroscedasticity. This violates one of the key assumptions of linear regression.

# %% [markdown]
# ### Independence of Errors

# %%
from statsmodels.stats.stattools import durbin_watson

# Durbin-Watson Test
dw_stat = durbin_watson(residuals)
print("Durbin-Watson statistic:", dw_stat)
# Out:
# Durbin-Watson statistic: 2.0085728401623637

# %% [markdown]
# This value is extremely close to 2, which suggests that there is no significant autocorrelation in the residuals.
# This supports the assumption of independent residuals, a key assumption in linear regression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Number of samples (rows) and features (columns) in the test set
n = X_test.shape[0]  # Number of observations
p = X_test.shape[1]  # Number of predictors

# Compute R2 score
r2 = r2_score(y_test, y_pred)

# Compute Adjusted R2 score
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

# Evaluate the model
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
print("Adjusted R2 Score:", adjusted_r2)
# Out:
# Mean Squared Error: 5.8788369421410085
# R2 Score: 0.9186721014610678
# Adjusted R2 Score: 0.9183968378044745

# %%
import pickle

with open('Linear_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# Some assumptions are not followed in this dataset. Linear regression does not perform well on this dataset. So we will try different algorithms

# %% [markdown]
# ## Decision Tree

# %%
X_train
# Out:
#        Category  Amount  Income  Savings  Monthly Expenses  Loan Payments  \
# 10315         6  144.79  135518    13025              1317            237
# 4245          5  244.61   42156    14880              1945            873
# 3728          4  274.82   66421    37031              5543           3145
# 10884         6  269.05  144867     4315              2826            220
# 11573         4  106.00  145957    27634              1568           1111
# ...         ...     ...     ...      ...               ...            ...
# 13418         0  438.33   96784    13445              3569           1836
# 5390          5   33.40  102357    15725              3057           2599
# 860           3  141.48  118696    34271              3175           4488
# 15795         6  177.97  128419    39962              5154           1624
# 7270          5  252.10   66434    32812              5469           4424
#
#        Credit Card Spending  Dependents  Financial Goals Met (%)  Day of Week  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Initialize the Decision Tree Regressor
regressor = DecisionTreeRegressor(random_state=42)

# Train the model
regressor.fit(X_train, y_train)

# Make predictions
y_pred = regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 5.376906884675524e-27
# R^2 Score: 1.0

# %%
with open('dt_model.pkl','wb') as f:
    pickle.dump(regressor,f)
